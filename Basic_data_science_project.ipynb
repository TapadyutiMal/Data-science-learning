# %% [markdown]
# <a href="https://colab.research.google.com/github/TapadyutiMal/Data-science-learning/blob/main/Basic_data_science_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Instead of 'error_bad_lines=False', use 'on_bad_lines='skip'' to skip bad lines
cc = pd.read_csv('/content/creditcard.csv', on_bad_lines='skip')

# If you want to handle bad lines in a specific way,
# use a custom function with the 'on_bad_lines' argument.
# For example, you can replace bad values with NaN.
# def handle_bad_lines(bad_line):
#    # Replace incorrect values with NaN
#    return ['NaN'] * 31 # assuming you expect 31 columns

# cc = pd.read_csv('/content/creditcard.csv', on_bad_lines=handle_bad_lines)
# Out:
# <ipython-input-13-3648adea2006>:6: DtypeWarning: Columns (1,2,3,4,5,6,8,10,11,12,13,16,20,21,23) have mixed types. Specify dtype option on import or set low_memory=False.
#   cc = pd.read_csv('/content/creditcard.csv', on_bad_lines='skip')

# %%
cc.head()
# Out:
#    Time        V1                   V2                V3        V4        V5  \
# 0   0.0 -1.359807  -0.0727811733098497  2.53634673796914  1.378155 -0.338321
# 1   0.0  1.191857     0.26615071205963  0.16648011335321  0.448154  0.060018
# 2   1.0 -1.358354    -1.34016307473609  1.77320934263119   0.37978 -0.503198
# 3   1.0 -0.966272   -0.185226008082898  1.79299333957872 -0.863291 -0.010309
# 4   2.0 -1.158233    0.877736754848451    1.548717846511  0.403034 -0.407193
#
#          V6        V7        V8        V9  ...       V21       V22       V23  \
# 0  0.462388  0.239599  0.098698  0.363787  ... -0.018307  0.277838 -0.110474
# 1 -0.082361 -0.078803  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288
# 2  1.800499  0.791461  0.247676 -1.514654  ...  0.247998  0.771679  0.909412
# 3  1.247203  0.237609  0.377436 -1.387024  ...   -0.1083  0.005274 -0.190321
# 4  0.095921  0.592941 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458
#
# ...

# %%
cc.tail()
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 535729  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 535730  172787.0  -0.732789   -0.05508   2.03503 -0.738589  0.868229
# 535731  172788.0   1.919565  -0.301254  -3.24964 -0.557828  2.630515
# 535732  172788.0   -0.24044   0.530483   0.70251  0.689799 -0.377961
# 535733  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# 535729 -2.606837 -4.918215  7.305334  1.914428  ...  0.213454  0.111864
# 535730  1.058415  0.024330  0.294869  0.584800  ...  0.214205  0.924384
# 535731   3.03126 -0.296827  0.708417  0.432454  ...  0.232045  0.578229
# 535732  0.623708 -0.686180  0.679145  0.392087  ...  0.265245  0.800049
# 535733 -0.649617  1.577006  -0.41465  0.486180  ...  0.261057  0.643078
#
#              V23       V24       V25       V26       V27       V28  Amount  \
# ...

# %% [markdown]
# Cleaning the data

# %%
cc.isnull().sum()
# Out:
# Time        0
# V1          0
# V2          0
# V3          2
# V4          2
# V5          3
# V6          3
# V7          3
# V8          6
# V9          8
# V10         9
# V11        13
# V12        16
# V13        22
# V14        26
# V15        30
# V16        34
# V17        40
# V18        43
# V19        47
# V20        58
# V21        60
# V22        65
# V23        71
# V24        79
# V25        85
# V26        89
# V27        96
# V28       107
# Amount    116
# Class     120
# dtype: int64

# %%
cc.dropna(inplace=True)
print(cc)
# Out:
#             Time         V1                   V2                V3        V4  \
# 0            0.0  -1.359807  -0.0727811733098497  2.53634673796914  1.378155
# 1            0.0   1.191857     0.26615071205963  0.16648011335321  0.448154
# 2            1.0  -1.358354    -1.34016307473609  1.77320934263119   0.37978
# 3            1.0  -0.966272   -0.185226008082898  1.79299333957872 -0.863291
# 4            2.0  -1.158233    0.877736754848451    1.548717846511  0.403034
# ...          ...        ...                  ...               ...       ...
# 535729  172786.0 -11.881118            10.071785         -9.834783 -2.066656
# 535730  172787.0  -0.732789             -0.05508           2.03503 -0.738589
# 535731  172788.0   1.919565            -0.301254          -3.24964 -0.557828
# 535732  172788.0   -0.24044             0.530483           0.70251  0.689799
# 535733  172792.0  -0.533413            -0.189733          0.703337 -0.506271
#
# ...

# %%
cc.shape
# Out:
# (535734, 31)

# %%
cc.describe()
# Out:
#                Time             V7             V9            V14  \
# count  5.357340e+05  535731.000000  535726.000000  535708.000000
# mean   2.444874e+12       0.007612      -0.017782      -0.018099
# std    1.607335e+15       1.238726       1.094191       0.962417
# min    0.000000e+00     -43.557242     -13.434066     -19.214325
# 25%    6.005925e+04      -0.550359      -0.651447      -0.436644
# 50%    9.406000e+04       0.047620      -0.060623       0.039722
# 75%    1.410520e+05       0.578772       0.573960       0.474841
# max    1.167879e+18     120.589494      86.000000     151.710000
#
#                  V15            V17            V18            V19  \
# count  535704.000000  535694.000000  535691.000000  535687.000000
# mean       -0.004294      -0.010507       0.021056       0.002347
# std         0.928689       0.877601       7.396740       0.815416
# min        -4.498945     -25.162799      -9.498746      -7.213527
# ...

# %%
non_fraud = len(cc[cc.Class == 0])

# %%
fraud = len(cc[cc.Class == 1])

# %%
fraud_pct = (fraud/(fraud+non_fraud))*100
fraud_pct
# Out:
# 0.1644841247614887

# %% [markdown]
# Machine learning model

# %% [markdown]
# Normalisation

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler

# %%
from sklearn.preprocessing import StandardScaler

# Create an instance of StandardScaler
scaler = StandardScaler() # The change is to add parentheses here

# Now you can use fit_transform() on the instance
cc['Normalized_amount'] = scaler.fit_transform(cc["Amount"].values.reshape(-1,1))

# %%
cc.drop(["Amount","Time"], inplace = True, axis=1)

# %%
cc.head()
# Out:
#          V1                   V2                V3        V4        V5  \
# 0 -1.359807  -0.0727811733098497  2.53634673796914  1.378155 -0.338321
# 1  1.191857     0.26615071205963  0.16648011335321  0.448154  0.060018
# 2 -1.358354    -1.34016307473609  1.77320934263119   0.37978 -0.503198
# 3 -0.966272   -0.185226008082898  1.79299333957872 -0.863291 -0.010309
# 4 -1.158233    0.877736754848451    1.548717846511  0.403034 -0.407193
#
#          V6        V7        V8        V9       V10  ...       V21       V22  \
# 0  0.462388  0.239599  0.098698  0.363787  0.090794  ... -0.018307  0.277838
# 1 -0.082361 -0.078803  0.085102 -0.255425 -0.166974  ... -0.225775 -0.638672
# 2  1.800499  0.791461  0.247676 -1.514654  0.207643  ...  0.247998  0.771679
# 3  1.247203  0.237609  0.377436 -1.387024 -0.054952  ...   -0.1083  0.005274
# 4  0.095921  0.592941 -0.270533  0.817739  0.753074  ... -0.009431  0.798278
#
#         V23       V24       V25       V26       V27       V28  Class  \
# ...

# %%
# for all independent variables
x = cc.drop(["Class"],axis=1)
y = cc["Class"]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size= 0.16, random_state=1)

# %%
x_train.shape
# Out:
# (449915, 29)

# %%
x_test.shape
# Out:
# (85699, 29)

# %% [markdown]
# create a model

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf1 = RandomForestClassifier(n_estimators = 100)

# %%
rf1.fit(x_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-61-f548204f8abb> in <cell line: 0>()
# ----> 1 rf1.fit(x_train, y_train)
#
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py in wrapper(estimator, *args, **kwargs)
#    1387                 )
#    1388             ):
# -> 1389                 return fit_method(estimator, *args, **kwargs)
#    1390
#    1391         return wrapper
#
# /usr/local/lib/python3.11/dist-packages/sklearn/ensemble/_forest.py in fit(self, X, y, sample_weight)
#     358             raise ValueError("sparse multilabel-indicator for y is not supported.")
#     359
# --> 360         X, y = validate_data(
#     361             self,
#     362             X,
#
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py in validate_data(_estimator, X, y, reset, validate_separately, skip_check_array, **check_params)
# ...
